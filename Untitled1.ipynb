# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bfuncs import clean_pcts
# %matplotlib inline

# %%
df = pd.read_csv('./data/AllTime/AllTimeSeasons.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89884 entries, 0 to 89883
# Data columns (total 45 columns):
# Unnamed: 0    89884 non-null int64
# Season        89884 non-null int64
# Name          89830 non-null object
# Team          89884 non-null object
# G             89884 non-null int64
# AB            89884 non-null int64
# PA            89884 non-null int64
# H             89884 non-null int64
# 1B            89884 non-null int64
# 2B            89884 non-null int64
# 3B            89884 non-null int64
# HR            89884 non-null int64
# R             89884 non-null int64
# RBI           89584 non-null float64
# BB            89884 non-null int64
# IBB           55941 non-null float64
# SO            82844 non-null float64
# HBP           87370 non-null float64
# SF            56457 non-null float64
# SH            84156 non-null float64
# GDP           65700 non-null float64
# SB            87784 non-null float64
# CS            68328 non-null float64
# ...

# %%
df['BB%'] = df['BB%'].apply(clean_pcts)
df['K%'] = df['K%'].apply(clean_pcts)

# %%
df.head()
# Out:
#    Unnamed: 0  Season               Name       Team  G  AB  PA  H  1B  2B  \
# 0           0    1874       Charlie Snow  Atlantics  1   1   1  1   1   0
# 1           1    1889  Sparrow McCaffrey     Solons  2   1   2  1   1   0
# 2           2    1893      Billy Gumbert   Colonels  1   1   1  1   0   1
# 3           3    1893     Frank O'Connor   Phillies  3   2   2  2   1   0
# 4           4    1897           Tom Lipp   Phillies  1   1   1  1   1   0
#
#    ...  wGDP  wSB  wRC  wRAA   wOBA   wRC+  BsR  Off  Def  WAR
# 0  ...   NaN  0.0    1   0.6  0.938  416.0  0.0  0.6 -1.0 -0.1
# 1  ...   NaN -0.1    1   0.9  0.869  383.0 -0.1  0.8  0.1  0.1
# 2  ...   NaN  0.0    1   0.8  1.308  600.0  0.0  0.8  0.0  0.1
# 3  ...   NaN  0.0    2   1.9  1.453  673.0  0.0  1.9  0.1  0.2
# 4  ...   NaN  0.0    1   0.5  0.961  429.0  0.0  0.5  0.0  0.0
#
# [5 rows x 45 columns]

# %%
nmgrp = df.groupby(['Name','playerid'])
szngrp = df.groupby(['Name', 'Season', 'playerid'])

# %%
sum_cols = ['G', 'AB', 'PA', 'H', '1B',
       '2B', '3B', 'HR', 'R', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SF', 'SH',
       'GDP', 'SB', 'CS', 'BsR', 'Off', 'Def', 'WAR']

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Season', 'Name', 'Team', 'G', 'AB', 'PA', 'H', '1B',
#        '2B', '3B', 'HR', 'R', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SF', 'SH',
#        'GDP', 'SB', 'CS', 'AVG', 'playerid', 'BB%', 'K%', 'BB/K', 'OBP', 'SLG',
#        'OPS', 'ISO', 'Spd', 'BABIP', 'UBR', 'wGDP', 'wSB', 'wRC', 'wRAA',
#        'wOBA', 'wRC+', 'BsR', 'Off', 'Def', 'WAR'],
#       dtype='object')

# %%
nmsum = nmgrp[sum_cols].sum()
nmsum.sort_values('WAR', ascending=False)[:25]
# Out:
#                               G     AB     PA     H    1B   2B   3B   HR  \
# Name             playerid
# Babe Ruth        1011327   2503   8398  10616  2873  1517  506  136  714
# Barry Bonds      1109      2986   9847  12606  2935  1495  601   77  762
# Willie Mays      1008315   2992  10881  12493  3283  1960  523  140  660
# Ty Cobb          1002378   3035  11434  13072  4189  3053  724  295  117
# Honus Wagner     1013485   2792  10430  11739  3415  2422  640  252  101
# Hank Aaron       1000001   3298  12364  13940  3771  2294  624   98  755
# Tris Speaker     1012309   2789  10195  11988  3514  2383  792  222  117
# Ted Williams     1014040   2292   7706   9791  2654  1537  525   71  521
# Rogers Hornsby   1006030   2259   8173   9475  2930  1919  541  169  301
# Stan Musial      1009405   3026  10972  12712  3630  2253  725  177  475
# Eddie Collins    1002451   2826   9949  12037  3315  2643  438  187   47
# ...

# %%
nmsum['HR'].sort_values(ascending=False)[:25]
# Out:
# Name              playerid
# Barry Bonds       1109        762
# Hank Aaron        1000001     755
# Babe Ruth         1011327     714
# Alex Rodriguez    1274        696
# Willie Mays       1008315     660
# Albert Pujols     1177        633
# Ken Griffey Jr.   327         630
# Jim Thome         409         612
# Sammy Sosa        302         609
# Frank Robinson    1011066     586
# Mark McGwire      1008559     583
# Harmon Killebrew  1006905     573
# Rafael Palmeiro   1266        569
# Reggie Jackson    1006308     563
# Manny Ramirez     210         555
# Mike Schmidt      1011586     548
# David Ortiz       745         541
# Mickey Mantle     1008082     536
# Jimmie Foxx       1004285     534
# Ted Williams      1014040     521
# Frank Thomas      255         521
# Willie McCovey    1008423     521
# Ernie Banks       1000512     512
# Eddie Mathews     1008236     512
# Mel Ott           1009904     511
# Name: HR, dtype: int64

# %%
nmsum['2B'].sort_values(ascending=False)[:25]
# Out:
# Name               playerid
# Tris Speaker       1012309     792
# Pete Rose          1011217     746
# Stan Musial        1009405     725
# Ty Cobb            1002378     724
# Craig Biggio       549         668
# George Brett       1001400     665
# Nap Lajoie         1007259     657
# Carl Yastrzemski   1014326     646
# Honus Wagner       1013485     640
# Albert Pujols      1177        639
# Adrian Beltre      639         636
# David Ortiz        745         632
# Hank Aaron         1000001     624
# Paul Molitor       1009040     605
# Paul Waner         1013597     605
# Cal Ripken         1010978     603
# Barry Bonds        1109        601
# Luis Gonzalez      55          596
# Todd Helton        432         592
# Rafael Palmeiro    1266        585
# Robin Yount        1014396     583
# Cap Anson          1000272     581
# Wade Boggs         1001124     578
# Charlie Gehringer  1004596     574
# Bobby Abreu        945         574
# Name: 2B, dtype: int64

# %%
nmsum['BB'].sort_values(ascending=False)[:25]
# Out:
# Name              playerid
# Barry Bonds       1109        2558
# Rickey Henderson  194         2190
# Babe Ruth         1011327     2062
# Ted Williams      1014040     2021
# Joe Morgan        1009179     1865
# Carl Yastrzemski  1014326     1845
# Jim Thome         409         1747
# Mickey Mantle     1008082     1733
# Mel Ott           1009904     1708
# Frank Thomas      255         1667
# Eddie Yost        1014357     1614
# Darrell Evans     1003864     1605
# Stan Musial       1009405     1599
# Pete Rose         1011217     1566
# Harmon Killebrew  1006905     1559
# Chipper Jones     97          1512
# Lou Gehrig        1004598     1508
# Mike Schmidt      1011586     1507
# Eddie Collins     1002451     1499
# Bobby Abreu       945         1476
# Gary Sheffield    114         1475
# Willie Mays       1008315     1464
# Jimmie Foxx       1004285     1452
# Eddie Mathews     1008236     1444
# Frank Robinson    1011066     1420
# Name: BB, dtype: int64

# %%
nmsum['3B'].sort_values(ascending=False)[:25]
# Out:
# Name               playerid
# Sam Crawford       1002748     309
# Ty Cobb            1002378     295
# Honus Wagner       1013485     252
# Jake Beckley       1000754     243
# Roger Connor       1002537     233
# Tris Speaker       1012309     222
# Fred Clarke        1002280     220
# Dan Brouthers      1001486     205
# Joe Kelley         1006776     194
# Paul Waner         1013597     191
# Bid McPhee         1008675     188
# Eddie Collins      1002451     187
# Ed Delahanty       1003155     185
# Sam Rice           1010900     184
# Ed Konetchy        1007093     182
# Jesse Burkett      1001682     182
# Edd Roush          1011247     182
# Buck Ewing         1003881     178
# Rabbit Maranville  1008099     177
# Stan Musial        1009405     177
# Harry Stovey       1012586     174
# Goose Goslin       1004893     173
# Tommy Leach        1007428     172
# Zack Wheat         1013828     172
# Rogers Hornsby     1006030     169
# Name: 3B, dtype: int64
